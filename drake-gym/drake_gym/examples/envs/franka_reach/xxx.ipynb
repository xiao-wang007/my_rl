# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Users/xiao/Downloads/week-8-worksheet-main/t2-graph/leeds-centre-air-quality.csv")
# data = pd.read_csv(r"E:\1850\作业\1.9\leeds-centre-air-quality.csv") # E:\1850\作业\1.9\leeds-centre-air-quality.csv is the file path on my local device

data = data.dropna()
x = [d for d in data['date']]
# y = ['{:.1f}'.format((data.iloc[i][1] + data.iloc[i][2] + data.iloc[i][3] + data.iloc[i][4]) / 4) for i in range(len(data))]
y = [(data.iloc[i][1] + data.iloc[i][2] + data.iloc[i][3] + data.iloc[i][4]) / 4 for i in range(len(data))]

# y = ['{:.1f}'.format((data[' pm25'][i] + data[' pm10'][i] + data[' o3'][i] + data[' no2'][i]) / 4) for i in range(len(data))]

# 经核算，上述代码与新代码所输出的数值相同，但存储形式不同

plt.plot(x, y)
plt.xlabel('date')
plt.ylabel('average air quality')
plt.title('Chengqi Li,\n StudentID: 201975989')

# plt.figure(figsize=(16,8))

plt.xticks(rotation=45)
plt.show()

len(y)
type(x)
# Out:
# /var/folders/md/3l82xnyx3rl73fjf1q6906040000gn/T/ipykernel_2596/790998702.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y = [(data.iloc[i][1] + data.iloc[i][2] + data.iloc[i][3] + data.iloc[i][4]) / 4 for i in range(len(data))]
# list

# %%
data['date'] = pd.to_datetime(data['date'], format='%y/%m/%d') 

x = data['date']
print(type(x))


z = data.iloc[:, 1:5].mean(axis=1)
# print(z)


plt.xticks(rotation=45)
plt.plot(x, z)
plt.show()
len(z)
# Out:
# <class 'pandas.core.series.Series'>
# 605

# %%
x
# Out:
# 0     2024-09-13
# 1     2024-09-12
# 2     2024-09-11
# 3     2024-09-10
# 4     2024-09-09
#          ...
# 600   2023-01-05
# 601   2023-01-04
# 602   2023-01-03
# 603   2023-01-02
# 604   2023-01-01
# Name: date, Length: 605, dtype: datetime64[ns]

# %%
data['date'].iloc[0]
# Out:
# Timestamp('2024-09-13 00:00:00')

# %%
data['date']
# Out:
# 0     2024-09-13
# 1     2024-09-12
# 2     2024-09-11
# 3     2024-09-10
# 4     2024-09-09
#          ...
# 600   2023-01-05
# 601   2023-01-04
# 602   2023-01-03
# 603   2023-01-02
# 604   2023-01-01
# Name: date, Length: 605, dtype: datetime64[ns]

# %%
x
# Out:
# 0     2024-09-13
# 1     2024-09-12
# 2     2024-09-11
# 3     2024-09-10
# 4     2024-09-09
#          ...
# 600   2023-01-05
# 601   2023-01-04
# 602   2023-01-03
# 603   2023-01-02
# 604   2023-01-01
# Name: date, Length: 605, dtype: datetime64[ns]
