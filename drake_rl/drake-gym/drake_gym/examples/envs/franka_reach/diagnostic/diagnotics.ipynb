# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
action_traj1 = np.load("action_trajectory_1.npy")
print(action_traj1.shape)
action_traj2 = np.load("action_trajectory_2.npy")
print(action_traj2.shape)
action_traj3 = np.load("action_trajectory_3.npy")
print(action_traj3.shape)
# Out:
# (51, 7)
# (51, 7)
# (51, 7)

# %%
ind_low = np.arange(0, 50)
ind_up = np.arange(1, 51)

delta_v1 = action_traj1[ind_up] - action_traj1[ind_low]
delta_v2 = action_traj2[ind_up] - action_traj2[ind_low]
delta_v3 = action_traj3[ind_up] - action_traj3[ind_low]

# %%
dv1_avg = np.mean(delta_v1, axis=0)
dv1_avg
# Out:
# array([ 0.0141614 , -0.0102177 , -0.04286378, -0.01421528,  0.00534819,
#         0.02828421, -0.00154119], dtype=float32)

# %%
dv1_std = np.std(delta_v1, axis=0)
dv1_std
# Out:
# array([1.4159412, 0.9937533, 1.118587 , 1.1656063, 1.2055327, 0.987984 ,
#        0.899182 ], dtype=float32)
